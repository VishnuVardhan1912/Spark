# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df = pd.DataFrame(np.random.randn(1000), columns=['data'], index = pd.date_range('2022/11/25', periods = 1000))

# %%
df
# Out:
#                 data
# 2022-11-25  0.144768
# 2022-11-26  1.061465
# 2022-11-27 -0.241602
# 2022-11-28  2.357024
# 2022-11-29  1.000592
# ...              ...
# 2025-08-16 -1.137378
# 2025-08-17 -1.044272
# 2025-08-18 -1.592977
# 2025-08-19  1.250094
# 2025-08-20  0.119302
#
# [1000 rows x 1 columns]

# %%
# It is difficult to know pattern of the dataset by seeing the data that is why we use graphs 

# Graph will give explination or pattern or behavior of dataset

# %%
df.plot(figsize = (20,10))  # pandas plt
# Out:
# <AxesSubplot:>

# %%
df = pd.read_csv("https://raw.githubusercontent.com/venky14/Machine-Learning-with-Iris-Dataset/master/Iris.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df = df.drop('Id', axis = 1)

# %%
df.plot(figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
df.iloc[5:11].plot(kind = 'bar', figsize = (20, 10))
# Out:
# <AxesSubplot:>

# %%
df.iloc[5:11]
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 5             5.4           3.9            1.7           0.4  Iris-setosa
# 6             4.6           3.4            1.4           0.3  Iris-setosa
# 7             5.0           3.4            1.5           0.2  Iris-setosa
# 8             4.4           2.9            1.4           0.2  Iris-setosa
# 9             4.9           3.1            1.5           0.1  Iris-setosa
# 10            5.4           3.7            1.5           0.2  Iris-setosa

# %%
df.iloc[[5]].plot(kind = 'bar', figsize = (20, 10))
# Out:
# <AxesSubplot:>

# %%
df.iloc[[5]]
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 5            5.4           3.9            1.7           0.4  Iris-setosa

# %%
df.iloc[[5]].plot(kind = 'barh', figsize = (20, 10))
# Out:
# <AxesSubplot:>

# %%
df.iloc[5:11].plot(kind = 'barh', figsize = (20, 10))
# Out:
# <AxesSubplot:>

# %%
df.plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df['SepalLengthCm'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['SepalLengthCm']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLengthCm, Length: 150, dtype: float64

# %%
df['SepalLengthCm'].plot(kind = 'hist', orientation = 'horizontal')
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# histogram as a function

df.hist(figsize=(20,10), color = 'g', alpha = 0.5) # alpha is intensity of color or color contast
# Out:
# array([[<AxesSubplot:title={'center':'SepalLengthCm'}>,
#         <AxesSubplot:title={'center':'SepalWidthCm'}>],
#        [<AxesSubplot:title={'center':'PetalLengthCm'}>,
#         <AxesSubplot:title={'center':'PetalWidthCm'}>]], dtype=object)

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# box plot - 


df.plot(kind='box', figsize=(20, 10), color='r')
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
df.plot(kind='box', figsize=(20, 10), color={'boxes': 'g', 'whiskers': 'r'}, vert = False)
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.plot(kind='area', figsize=(20, 10)) # It fills the area with color. It is a similar to line graph
# Out:
# <AxesSubplot:>

# %%
df.plot(figsize=(20, 10))
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='area', figsize=(20, 10), alpha = .4, stacked=True) # Stacked means graph does not over lap
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='area', figsize=(20, 10), alpha = .4, stacked=False)
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.plot.scatter(x = 'SepalLengthCm', y = 'PetalLengthCm')
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
df.plot.scatter(x = 'SepalLengthCm', y = 'PetalWidthCm')
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalWidthCm'>

# %%
df.plot.scatter(x = 'SepalLengthCm', y = 'PetalLengthCm', c = 'SepalWidthCm', s = 600) # In this graph c represent the color.
# s is size
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
df.plot.scatter(x = 'SepalLengthCm', y = 'PetalLengthCm', c = 'SepalWidthCm', s = df['PetalWidthCm']*500)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
df.plot.hexbin(x = 'SepalLengthCm', y = 'PetalLengthCm', C = 'SepalWidthCm', gridsize=10)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.iloc[0]
# Out:
# SepalLengthCm            5.1
# SepalWidthCm             3.5
# PetalLengthCm            1.4
# PetalWidthCm             0.2
# Species          Iris-setosa
# Name: 0, dtype: object

# %%
df1 = df.drop(columns='Species').iloc[0]

# %%
df1.plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='0'>

# %% [markdown]
# ## Plotly

# %% [raw]
# plotly library is a interactive than other libraries

# %%
# !pip install plotly
# !pip install cufflinks # cufflinks is offline version of plotly
# !pip install chart_studio. chart_studio is required outside of offline mode: please run pip install chart_studio

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df.iplot()
# Out:
# <div>                            <div id="ffa5c395-c64f-4fec-b866-e544827148bf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [raw]
# difference between ploting a graph and dashbord tool
#
# In dashbording tool we try to draw different kpi's, data modelling and integration with data and schedular. in automatic way keep on generating reports
# graph is a relation between the dataset

# %%
# scatter plot

df.iplot(x='SepalLengthCm', y='PetalLengthCm', mode = 'markers')
# Out:
# <div>                            <div id="04bb69bb-f06a-408a-9315-79b529ce341a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x='SepalLengthCm', y='PetalLengthCm', kind = 'scatter', mode='markers')
# Out:
# <div>                            <div id="fb480376-7284-4d8a-b30b-bd4e64d45c76" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='scatter', mode='markers', size = 5)
# Out:
# <div>                            <div id="f8fd7159-a46f-4362-a654-78ec7f3e04fd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='bubble', x = 'SepalLengthCm', y = 'PetalLengthCm', size='SepalWidthCm')
# Out:
# <div>                            <div id="a81b856e-b3cb-44cd-8f46-56fb21738240" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.scatter_matrix() # It is a combination of histogram and scatter plot
# Out:
# <div>                            <div id="010de3b8-7565-481a-915c-167de00e3507" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.iplot(kind='scatter3d', x ='SepalLengthCm',y = 'SepalWidthCm',z='PetalLengthCm')
# Out:
# <div>                            <div id="5976e67b-e438-4024-b406-8caff0924eb4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.head().iplot(kind='scatter3d', x ='SepalLengthCm',y = 'SepalWidthCm',z='PetalLengthCm')
# Out:
# <div>                            <div id="339fdfd5-a428-4ff3-9c34-bede1e34c59a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.iplot(kind='bubble3d', x ='SepalLengthCm',y = 'SepalWidthCm',z='PetalLengthCm', size= 'PetalWidthCm')
# Out:
# <div>                            <div id="146df93a-1f27-4e90-9dc8-84805b110035" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [raw]
# Homework -
#
# try to explore map graph and try to show and example (2-3)
